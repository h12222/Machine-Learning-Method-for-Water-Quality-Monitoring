# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_excel("final_dataset.xlsx")
df
# Out:
#       cod     tss    bod    ph  ammonia   temp    do  Unnamed: 7  Unnamed: 8  \
# 0   26.66   43.22   9.10  7.57     3.41  25.70  6.83         NaN         NaN
# 1   12.39  347.56   0.79  8.04     0.74  28.80  4.59         NaN         NaN
# 2   11.53  108.66   1.16  8.01     1.39  27.03  6.67         NaN         NaN
# 3    9.97   93.68   1.69  7.66     2.01  26.30  7.79         NaN         NaN
# 4   12.45   53.61   0.99  8.00     6.10  27.30  7.55         NaN         NaN
# ..    ...     ...    ...   ...      ...    ...   ...         ...         ...
# 87  70.97   72.89  30.13  7.63     9.38  25.40  0.25         NaN         NaN
# 88  78.55   59.69  20.72  7.33     9.97  26.50  0.30         NaN         NaN
# 89   1.59    0.00   1.04  7.53     1.10  27.40  6.52         NaN         NaN
# 90  12.91   53.70   2.26  7.80     1.04  27.40  4.09         NaN         NaN
# 91   9.00    0.00   3.00  7.10     0.86  20.50  9.78         NaN         NaN
#
#     Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12       COD       TSS  \
# 0          NaN          NaN          NaN          NaN  0.135785  0.113382
# 1          NaN          NaN          NaN          NaN  0.063105  0.911776
# 2          NaN          NaN          NaN          NaN  0.058725  0.285055
# 3          NaN          NaN          NaN          NaN  0.050779  0.245757
# 4          NaN          NaN          NaN          NaN  0.063410  0.140639
# ..         ...          ...          ...          ...       ...       ...
# 87         NaN          NaN          NaN          NaN  0.361465  0.191217
# 88         NaN          NaN          NaN          NaN  0.400071  0.156589
# 89         NaN          NaN          NaN          NaN  0.008098  0.000000
# 90         NaN          NaN          NaN          NaN  0.065753  0.140875
# 91         NaN          NaN          NaN          NaN  0.045839  0.000000
#
#          BOD        PH   Ammonia      Temp        DO
# 0   0.023873  0.038592  0.013903  0.371622  0.583189
# 1   0.002072  0.045818  0.002722  0.581081  0.389081
# 2   0.003043  0.045357  0.005444  0.461486  0.569324
# 3   0.004433  0.039975  0.008041  0.412162  0.666378
# 4   0.002597  0.045203  0.025169  0.479730  0.645581
# ..       ...       ...       ...       ...       ...
# 87  0.079042  0.039514  0.038904  0.351351  0.012998
# 88  0.054356  0.034902  0.041375  0.425676  0.017331
# 89  0.002728  0.037977  0.004230  0.486486  0.556326
# 90  0.005929  0.042128  0.003978  0.486486  0.345754
# 91  0.007870  0.031365  0.003225  0.020270  0.838821
#
# [92 rows x 20 columns]

# %%
dfs=df.round(3)
dfs
# Out:
#       cod     tss    bod    ph  ammonia   temp    do  Unnamed: 7  Unnamed: 8  \
# 0   26.66   43.22   9.10  7.57     3.41  25.70  6.83         NaN         NaN
# 1   12.39  347.56   0.79  8.04     0.74  28.80  4.59         NaN         NaN
# 2   11.53  108.66   1.16  8.01     1.39  27.03  6.67         NaN         NaN
# 3    9.97   93.68   1.69  7.66     2.01  26.30  7.79         NaN         NaN
# 4   12.45   53.61   0.99  8.00     6.10  27.30  7.55         NaN         NaN
# ..    ...     ...    ...   ...      ...    ...   ...         ...         ...
# 87  70.97   72.89  30.13  7.63     9.38  25.40  0.25         NaN         NaN
# 88  78.55   59.69  20.72  7.33     9.97  26.50  0.30         NaN         NaN
# 89   1.59    0.00   1.04  7.53     1.10  27.40  6.52         NaN         NaN
# 90  12.91   53.70   2.26  7.80     1.04  27.40  4.09         NaN         NaN
# 91   9.00    0.00   3.00  7.10     0.86  20.50  9.78         NaN         NaN
#
#     Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12    COD    TSS    BOD  \
# 0          NaN          NaN          NaN          NaN  0.136  0.113  0.024
# 1          NaN          NaN          NaN          NaN  0.063  0.912  0.002
# 2          NaN          NaN          NaN          NaN  0.059  0.285  0.003
# 3          NaN          NaN          NaN          NaN  0.051  0.246  0.004
# 4          NaN          NaN          NaN          NaN  0.063  0.141  0.003
# ..         ...          ...          ...          ...    ...    ...    ...
# 87         NaN          NaN          NaN          NaN  0.361  0.191  0.079
# 88         NaN          NaN          NaN          NaN  0.400  0.157  0.054
# 89         NaN          NaN          NaN          NaN  0.008  0.000  0.003
# 90         NaN          NaN          NaN          NaN  0.066  0.141  0.006
# 91         NaN          NaN          NaN          NaN  0.046  0.000  0.008
#
#        PH  Ammonia   Temp     DO
# 0   0.039    0.014  0.372  0.583
# 1   0.046    0.003  0.581  0.389
# 2   0.045    0.005  0.461  0.569
# 3   0.040    0.008  0.412  0.666
# 4   0.045    0.025  0.480  0.646
# ..    ...      ...    ...    ...
# 87  0.040    0.039  0.351  0.013
# 88  0.035    0.041  0.426  0.017
# 89  0.038    0.004  0.486  0.556
# 90  0.042    0.004  0.486  0.346
# 91  0.031    0.003  0.020  0.839
#
# [92 rows x 20 columns]

# %%
#Taking the independent Parameters of the dataset
X=dfs[["TSS","BOD","PH","Ammonia","Temp","DO"]]
X
# Out:
#       TSS    BOD     PH  Ammonia   Temp     DO
# 0   0.113  0.024  0.039    0.014  0.372  0.583
# 1   0.912  0.002  0.046    0.003  0.581  0.389
# 2   0.285  0.003  0.045    0.005  0.461  0.569
# 3   0.246  0.004  0.040    0.008  0.412  0.666
# 4   0.141  0.003  0.045    0.025  0.480  0.646
# ..    ...    ...    ...      ...    ...    ...
# 87  0.191  0.079  0.040    0.039  0.351  0.013
# 88  0.157  0.054  0.035    0.041  0.426  0.017
# 89  0.000  0.003  0.038    0.004  0.486  0.556
# 90  0.141  0.006  0.042    0.004  0.486  0.346
# 91  0.000  0.008  0.031    0.003  0.020  0.839
#
# [92 rows x 6 columns]

# %%
#Taking the Target parameters of the dataset
y=dfs["COD"]
y
# Out:
# 0     0.136
# 1     0.063
# 2     0.059
# 3     0.051
# 4     0.063
#       ...
# 87    0.361
# 88    0.400
# 89    0.008
# 90    0.066
# 91    0.046
# Name: COD, Length: 92, dtype: float64

# %%
# Out:
# <AxesSubplot:>

# %%
#Tarining and testing the data
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.6,random_state=1)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
regressor = LinearRegression()  
regressor.fit(X_train, y_train) #training the algorithm
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([0.04139805, 0.05198279, 0.04469723, 0.05017357, 0.02307215,
#        0.02081288, 0.02081288, 0.05745762, 0.02767242, 0.02253975,
#        0.05240541, 0.09696644, 0.05745762, 0.05872316, 0.02253975,
#        0.02081288, 0.02898323, 0.05968227, 0.04744595, 0.01324822,
#        0.05198279, 0.39866945, 0.34023026, 0.05964768, 0.05070191,
#        0.06648161, 0.37379647, 0.01362174, 0.05180068, 0.02307215,
#        0.01362174, 0.01713222, 0.05240541, 0.05552633, 0.01894611,
#        0.01184352, 0.56995082])

# %%
#To retrieve the intercept:
print(regressor.intercept_)
# Out:
# 0.015573170808050901

# %%
#For retrieving the slope:
print(regressor.coef_)
# Out:
# [ 0.16183323  6.29581409  0.01207549  0.0269458  -0.0195067  -0.02212012]

# %%
# Accuracy Of the Data
regressor.score(X_test,y_test)
# Out:
# 0.949288810570573

# %%
dfs = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
dfs
# Out:
#     Actual  Predicted
# 59   0.046   0.041398
# 73   0.046   0.051983
# 44   0.032   0.044697
# 56   0.046   0.050174
# 74   0.046   0.023072
# 81   0.036   0.020813
# 84   0.036   0.020813
# 53   0.046   0.057458
# 54   0.047   0.027672
# 39   0.046   0.022540
# 40   0.046   0.052405
# 31   0.000   0.096966
# 80   0.046   0.057458
# 27   0.058   0.058723
# 38   0.046   0.022540
# 55   0.036   0.020813
# 10   0.098   0.028983
# 2    0.059   0.059682
# 91   0.046   0.047446
# 89   0.008   0.013248
# 48   0.046   0.051983
# 19   0.380   0.398669
# 86   0.425   0.340230
# 36   0.066   0.059648
# 33   0.046   0.050702
# 32   0.094   0.066482
# 46   0.400   0.373796
# 67   0.046   0.013622
# 65   0.046   0.051801
# 52   0.046   0.023072
# 35   0.046   0.013622
# 41   0.008   0.017132
# 70   0.046   0.052405
# 23   0.035   0.055526
# 34   0.036   0.018946
# 78   0.045   0.011844
# 45   0.589   0.569951

# %%
# Accuracy Of the Testing Data
regressor.score(X_test,y_test)
# Out:
# 0.949288810570573

# %%
#Accuracy of training Data
regressor.score(X_train,y_train)
# Out:
# 0.9285873029244376

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.019962242564288586
# Mean Squared Error: 0.0008502439530965266
# Root Mean Squared Error: 0.029158942935170448

# %%
from sklearn.linear_model import Lasso
lasso_regressor=Lasso()
lasso_regressor.fit(X_train,y_train)
prediction_lasso=lasso_regressor.predict(X_test)
prediction_lasso
# Out:
# array([0.17498182, 0.17498182, 0.17498182, 0.17498182, 0.17498182,
#        0.17498182, 0.17498182, 0.17498182, 0.17498182, 0.17498182,
#        0.17498182, 0.17498182, 0.17498182, 0.17498182, 0.17498182,
#        0.17498182, 0.17498182, 0.17498182, 0.17498182, 0.17498182,
#        0.17498182, 0.17498182, 0.17498182, 0.17498182, 0.17498182,
#        0.17498182, 0.17498182, 0.17498182, 0.17498182, 0.17498182,
#        0.17498182, 0.17498182, 0.17498182, 0.17498182, 0.17498182,
#        0.17498182, 0.17498182])

# %%
print("Lasso")
df = pd.DataFrame({'Actual': y_test, 'Predicted': prediction_lasso})
df
# Out:
# Lasso
#     Actual  Predicted
# 59   0.046   0.174982
# 73   0.046   0.174982
# 44   0.032   0.174982
# 56   0.046   0.174982
# 74   0.046   0.174982
# 81   0.036   0.174982
# 84   0.036   0.174982
# 53   0.046   0.174982
# 54   0.047   0.174982
# 39   0.046   0.174982
# 40   0.046   0.174982
# 31   0.000   0.174982
# 80   0.046   0.174982
# 27   0.058   0.174982
# 38   0.046   0.174982
# 55   0.036   0.174982
# 10   0.098   0.174982
# 2    0.059   0.174982
# 91   0.046   0.174982
# 89   0.008   0.174982
# 48   0.046   0.174982
# 19   0.380   0.174982
# 86   0.425   0.174982
# 36   0.066   0.174982
# 33   0.046   0.174982
# 32   0.094   0.174982
# 46   0.400   0.174982
# 67   0.046   0.174982
# 65   0.046   0.174982
# 52   0.046   0.174982
# 35   0.046   0.174982
# 41   0.008   0.174982
# 70   0.046   0.174982
# 23   0.035   0.174982
# 34   0.036   0.174982
# 78   0.045   0.174982
# 45   0.589   0.174982

# %%
lasso_regressor.score(X_test,y_test)
# Out:
# -0.4473325795709948

# %%
lasso_regressor.score(X_train,y_train)
# Out:
# 0.0

# %%
print("Lasso Regression")
mae_lasso=metrics.mean_absolute_error(y_test,prediction_lasso)
print('Mean Absolute Error:',mae_lasso)    
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, prediction_lasso)))
# Out:
# Lasso Regression
# Mean Absolute Error: 0.14574250614250614
# Root Mean Squared Error: 0.15577725493836173

# %%
from sklearn.linear_model import Ridge
ridge_regressor=Ridge()
ridge_regressor.fit(X_train,y_train)
prediction_ridge=ridge_regressor.predict(X_test)
prediction_ridge
# Out:
# array([ 0.04261487,  0.12115632,  0.12191875,  0.0509774 ,  0.03759771,
#         0.09588871,  0.09588871,  0.181443  ,  0.06527916,  0.06951846,
#         0.13905061,  0.20710442,  0.181443  ,  0.16606188,  0.06951846,
#         0.09588871,  0.02266342,  0.1519323 ,  0.05013296,  0.0744492 ,
#         0.12115632,  0.32708056,  0.3981351 ,  0.19070713,  0.04994707,
#        -0.086562  ,  0.33690031,  0.12786353,  0.13427267,  0.03759771,
#         0.12786353,  0.08100813,  0.13905061,  0.3617618 ,  0.06812399,
#         0.03832534,  0.35822499])

# %%
print("Ridge")
df = pd.DataFrame({'Actual': y_test, 'Predicted': prediction_ridge})
df
# Out:
# Ridge
#     Actual  Predicted
# 59   0.046   0.042615
# 73   0.046   0.121156
# 44   0.032   0.121919
# 56   0.046   0.050977
# 74   0.046   0.037598
# 81   0.036   0.095889
# 84   0.036   0.095889
# 53   0.046   0.181443
# 54   0.047   0.065279
# 39   0.046   0.069518
# 40   0.046   0.139051
# 31   0.000   0.207104
# 80   0.046   0.181443
# 27   0.058   0.166062
# 38   0.046   0.069518
# 55   0.036   0.095889
# 10   0.098   0.022663
# 2    0.059   0.151932
# 91   0.046   0.050133
# 89   0.008   0.074449
# 48   0.046   0.121156
# 19   0.380   0.327081
# 86   0.425   0.398135
# 36   0.066   0.190707
# 33   0.046   0.049947
# 32   0.094  -0.086562
# 46   0.400   0.336900
# 67   0.046   0.127864
# 65   0.046   0.134273
# 52   0.046   0.037598
# 35   0.046   0.127864
# 41   0.008   0.081008
# 70   0.046   0.139051
# 23   0.035   0.361762
# 34   0.036   0.068124
# 78   0.045   0.038325
# 45   0.589   0.358225

# %%
print("Ridge Regression")
mae_ridge=metrics.mean_absolute_error(y_test, prediction_ridge)
print('Mean Absolute Error:',mae_ridge )   
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, prediction_ridge)))
# Out:
# Ridge Regression
# Mean Absolute Error: 0.0782386168260469
# Root Mean Squared Error: 0.10428482175264024

# %%
from sklearn.linear_model import ElasticNet
model_enet = ElasticNet()
model_enet.fit(X_train, y_train) 
prediction_elasticnet= model_enet.predict(X_test)
prediction_elasticnet
# Out:
# array([0.17498182, 0.17498182, 0.17498182, 0.17498182, 0.17498182,
#        0.17498182, 0.17498182, 0.17498182, 0.17498182, 0.17498182,
#        0.17498182, 0.17498182, 0.17498182, 0.17498182, 0.17498182,
#        0.17498182, 0.17498182, 0.17498182, 0.17498182, 0.17498182,
#        0.17498182, 0.17498182, 0.17498182, 0.17498182, 0.17498182,
#        0.17498182, 0.17498182, 0.17498182, 0.17498182, 0.17498182,
#        0.17498182, 0.17498182, 0.17498182, 0.17498182, 0.17498182,
#        0.17498182, 0.17498182])

# %%
print("Elastic Net")
df = pd.DataFrame({'Actual': y_test, 'Predicted': prediction_elasticnet})
df
# Out:
# Elastic Net
#     Actual  Predicted
# 59   0.046   0.174982
# 73   0.046   0.174982
# 44   0.032   0.174982
# 56   0.046   0.174982
# 74   0.046   0.174982
# 81   0.036   0.174982
# 84   0.036   0.174982
# 53   0.046   0.174982
# 54   0.047   0.174982
# 39   0.046   0.174982
# 40   0.046   0.174982
# 31   0.000   0.174982
# 80   0.046   0.174982
# 27   0.058   0.174982
# 38   0.046   0.174982
# 55   0.036   0.174982
# 10   0.098   0.174982
# 2    0.059   0.174982
# 91   0.046   0.174982
# 89   0.008   0.174982
# 48   0.046   0.174982
# 19   0.380   0.174982
# 86   0.425   0.174982
# 36   0.066   0.174982
# 33   0.046   0.174982
# 32   0.094   0.174982
# 46   0.400   0.174982
# 67   0.046   0.174982
# 65   0.046   0.174982
# 52   0.046   0.174982
# 35   0.046   0.174982
# 41   0.008   0.174982
# 70   0.046   0.174982
# 23   0.035   0.174982
# 34   0.036   0.174982
# 78   0.045   0.174982
# 45   0.589   0.174982

# %%
model_enet.score(X_test,y_test)
# Out:
# -0.4473325795709948

# %%
model_enet.score(X_train,y_train)
# Out:
# 0.0

# %%
print("Elastic_net Regression")
mae_elasticnet=metrics.mean_absolute_error(y_test, prediction_elasticnet)
print('Mean Absolute Error:',mae_elasticnet )   
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, prediction_elasticnet)))
# Out:
# Elastic_net Regression
# Mean Absolute Error: 0.14574250614250614
# Root Mean Squared Error: 0.15577725493836173
